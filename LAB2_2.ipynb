# %% [markdown]
# # LAB 2.2

# %%
#user for age and convert to integer
age = int(input("Enter your age: "))

#recommendation logic
if age < 5:
    print("You're too young for movies! Enjoy cartoons.")
elif 5 <= age <= 12:
    print("Recommend G-rated or PG-rated movies.")
elif 13 <= age <= 17:
    print("Recommend PG-13 or R-rated (with parental guidance).")
else:
    #Challenge: Logic for age 18 or older
    print("Recommend Any movie rating.")

    action_pref = input("Do you like action movies? (yes/no): ").lower()
    if action_pref == "yes":
        print("You might enjoy the latest action blockbuster!")
# Out:
# Enter your age: 20
# Recommend Any movie rating.
# Do you like action movies? (yes/no): yes
# You might enjoy the latest action blockbuster!
